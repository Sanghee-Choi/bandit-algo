# %%
from scipy.stats import norm
import numpy as np
import matplotlib.pyplot as plt

# %%
mean, var, skew, kurt = norm.stats(moments='mvsk')

# %%
fig, ax = plt.subplots(1, 1)
x = np.linspace(norm.ppf(0.01), norm.ppf(0.99), 100)
ax.plot(x, norm.pdf(x), 'r-', lw=5, alpha=0.6, label='norm pdf')

# %%
fig, ax = plt.subplots(1, 1)
rv = norm()
ax.plot(x, rv.pdf(x), 'k-', lw=2, label='frozen pdf')

# %%
vals = norm.ppf([0.001, 0.5, 0.999])
np.allclose([0.001, 0.5, 0.999], norm.cdf(vals))
# Out:
# True

# %%
fig, ax = plt.subplots(1, 1)
r = norm.rvs(size=1000)
ax.hist(r, density=True, histtype='stepfilled', alpha=0.2)
ax.plot(x, norm.pdf(x), 'r-', lw=5, alpha=0.6, label='norm pdf')
ax.plot(x, rv.pdf(x), 'k-', lw=2, label='frozen pdf')
ax.legend(loc='best', frameon=False)
plt.show()

# %%
from scipy.stats import uniform

# %%
uniform.rvs(3)
# Out:
# 3.4123368810705474

# %%
class a():
    def __init__(self, name):
        self.name = name

# %%
aa = a('UCB')

# %%
aa.name
# Out:
# 'UCB'

# %%
means = np.random.normal(0, 1, 10)
means
# Out:
# array([ 1.2962802 ,  1.33186187,  0.14327129, -1.95154084, -0.1501361 ,
#         1.02403401, -0.21650542, -0.91027567, -1.01070256, -0.25621142])

# %%
np.random.uniform(size=10)
# Out:
# array([0.38636379, 0.57440655, 0.08909764, 0.82199908, 0.90348347,
#        0.97796876, 0.26485674, 0.659143  , 0.1935698 , 0.34021846])
